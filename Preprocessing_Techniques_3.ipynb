# %%
import pandas as pd

# %%
#loading the dataset

data1=pd.read_csv("/Users/sumaiyairshad/Desktop/MS in Data Science/PRACTICE_DATASETS/tips.csv")

# %%
data1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Applying the groupby() fuction on the column - time
G1= data1.groupby("time")

# %%
# Printing the first entries of each group
G1.first()
# Out:
#         total_bill   tip     sex smoker   day  size
# time
# Dinner       16.99  1.01  Female     No   Sun     2
# Lunch        27.20  4.00    Male     No  Thur     4

# %%
##Finding the values present in 'Dinner' group

G1.get_group('Dinner')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
#Values present in Lunch group


G1.get_group('Lunch')
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 78        22.76  3.00    Male     No  Thur  Lunch     2
# 79        17.29  2.71    Male     No  Thur  Lunch     2
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 81        16.66  3.40    Male     No  Thur  Lunch     2
# ..          ...   ...     ...    ...   ...    ...   ...
# 222        8.58  1.92    Male    Yes   Fri  Lunch     1
# 223       15.98  3.00  Female     No   Fri  Lunch     3
# 224       13.42  1.58    Male    Yes   Fri  Lunch     2
# 225       16.27  2.50  Female    Yes   Fri  Lunch     2
# 226       10.09  2.00  Female    Yes   Fri  Lunch     2
#
# [68 rows x 7 columns]

# %%
##AGGREGATE FUNCTION

data1[['total_bill','tip','size']].aggregate(['sum','min'])

##THIS WILL ONLY WORK FOR NUMERICAL COLUMN
# Out:
#      total_bill     tip  size
# sum     4827.77  731.58   627
# min        3.07    1.00     1

# %%
##Applying the 'average' operation on the column 'total_bill'

data1['total_bill'].aggregate(['average'])
# Out:
# average    19.785943
# Name: total_bill, dtype: float64

# %%
##TIME SERIES OPERATION

import matplotlib.pyplot as plt

# Create a time series DataFrame with dates over five days
dates = pd.date_range(start='2022-01-01', periods=5, freq='D')
data = [5, 8, 6, 9, 7]
df = pd.DataFrame(data, columns=['Value'], index=dates)

# Plot the data
df.plot(title="Simple Time Series Plot", grid=True)
plt.show()
